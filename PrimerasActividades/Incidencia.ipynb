# %% [markdown]
# <a href="https://colab.research.google.com/github/aledelorbe/pt2Codigos/blob/main/PrimerasActividades/Incidencia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Cargar librerias

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Cargar los dataFrame

# %%
incidencia = '/content/drive/MyDrive/Pt2/Primeras Actividades/0 Bases de Datos/Incidencia/'

df2010 = pd.read_csv(incidencia + 'Inc_2010.csv')
df2011 = pd.read_csv(incidencia + 'Inc_2011.csv')
df2012 = pd.read_csv(incidencia + 'Inc_2012.csv')
df2013 = pd.read_csv(incidencia + 'Inc_2013.csv')
df2014 = pd.read_csv(incidencia + 'Inc_2014.csv')
df2015 = pd.read_csv(incidencia + 'Inc_2015.csv')
df2016 = pd.read_csv(incidencia + 'Inc_2016.csv')
df2017 = pd.read_csv(incidencia + 'Inc_2017.csv')
df2018 = pd.read_csv(incidencia + 'Inc_2018.csv')
df2019 = pd.read_csv(incidencia + 'Inc_2019.csv')

# %% [markdown]
# # Análisis general ---------------------------------------------------------------------------------------------

# %%
print("DataFrame 2010".center(100, '-'))
print(df2010[['edad', 'sexo', 'ent_regis', 'ent_mx', 'mun_regis']].describe())
print(df2010[['munic_mx', 'diag_ini', 'ICD', 'organ', 'month_year_ocurr']].describe())
print("DataFrame 2011".center(100, '-'))
print(df2011[['edad', 'sexo', 'ent_regis', 'ent_mx', 'mun_regis']].describe())
print(df2011[['munic_mx', 'diag_ini', 'ICD', 'organ', 'month_year_ocurr']].describe())
print("DataFrame 2012".center(100, '-'))
print(df2012[['edad', 'sexo', 'ent_regis', 'ent_mx', 'mun_regis']].describe())
print(df2012[['munic_mx', 'diag_ini', 'ICD', 'organ', 'month_year_ocurr']].describe())
print("DataFrame 2013".center(100, '-'))
print(df2013[['edad', 'sexo', 'ent_regis', 'ent_mx', 'mun_regis']].describe())
print(df2013[['munic_mx', 'diag_ini', 'ICD', 'organ', 'month_year_ocurr']].describe())
print("DataFrame 2014".center(100, '-'))
print(df2014[['edad', 'sexo', 'ent_regis', 'ent_mx', 'mun_regis']].describe())
print(df2014[['munic_mx', 'diag_ini', 'ICD', 'organ', 'month_year_ocurr']].describe())
print("DataFrame 2015".center(100, '-'))
print(df2015[['edad', 'sexo', 'ent_regis', 'ent_mx', 'mun_regis']].describe())
print(df2015[['munic_mx', 'diag_ini', 'ICD', 'organ', 'month_year_ocurr']].describe())
print("DataFrame 2016".center(100, '-'))
print(df2016[['edad', 'sexo', 'ent_regis', 'ent_mx', 'mun_regis']].describe())
print(df2016[['munic_mx', 'diag_ini', 'ICD', 'organ', 'month_year_ocurr']].describe())
print("DataFrame 2017".center(100, '-'))
print(df2017[['edad', 'sexo', 'ent_regis', 'ent_mx', 'mun_regis']].describe())
print(df2017[['munic_mx', 'diag_ini', 'ICD', 'organ', 'month_year_ocurr']].describe())
print("DataFrame 2018".center(100, '-'))
print(df2018[['edad', 'sexo', 'ent_regis', 'ent_mx', 'mun_regis']].describe())
print(df2018[['munic_mx', 'diag_ini', 'ICD', 'organ', 'month_year_ocurr']].describe())
print("DataFrame 2019".center(100, '-'))
print(df2019[['edad', 'sexo', 'ent_regis', 'ent_mx', 'mun_regis']].describe())
print(df2019[['munic_mx', 'diag_ini', 'ICD', 'organ', 'month_year_ocurr']].describe())
# Out:
# -------------------------------------------DataFrame 2010-------------------------------------------
#                edad          sexo     ent_regis     mun_regis
# count  70875.000000  70875.000000  70875.000000  70875.000000
# mean      41.115132      1.610892     15.883302  15958.885587
# std       26.294370      0.498767      7.761930   7775.124586
# min        1.000000      1.000000      1.000000   1001.000000
# 25%       18.000000      1.000000     11.000000  11017.000000
# 50%       44.000000      2.000000     15.000000  15033.000000
# 75%       59.000000      2.000000     20.000000  20364.000000
# max      999.000000      9.000000     35.000000  35999.000000
#            munic_mx diag_ini    ICD     organ month_year_ocurr
# count         70834    70875  70875     70875            70875
# unique         1897      429     36        36               13
# top     Guadalajara     C910    C95  Leukemia          2010-10
# ...

# %% [markdown]
# # Análisis para el cáncer --------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Verificar si en alguno de los dataFrames el campo ICD contiene valores nulos

# %%
isNuloICD2010 = df2010['ICD'].isnull().any()
isNuloICD2011 = df2011['ICD'].isnull().any()
isNuloICD2012 = df2012['ICD'].isnull().any()
isNuloICD2013 = df2013['ICD'].isnull().any()
isNuloICD2014 = df2014['ICD'].isnull().any()
isNuloICD2015 = df2015['ICD'].isnull().any()
isNuloICD2016 = df2016['ICD'].isnull().any()
isNuloICD2017 = df2017['ICD'].isnull().any()
isNuloICD2018 = df2018['ICD'].isnull().any()
isNuloICD2019 = df2019['ICD'].isnull().any()

print('DataSet2010 ICD: ', isNuloICD2010)
print('DataSet2011 ICD: ', isNuloICD2011)
print('DataSet2012 ICD: ', isNuloICD2012)
print('DataSet2013 ICD: ', isNuloICD2013)
print('DataSet2014 ICD: ', isNuloICD2014)
print('DataSet2015 ICD: ', isNuloICD2015)
print('DataSet2016 ICD: ', isNuloICD2016)
print('DataSet2017 ICD: ', isNuloICD2017)
print('DataSet2018 ICD: ', isNuloICD2018)
print('DataSet2019 ICD: ', isNuloICD2019)

# Se concluye que NO hay valores nulos en la columna ICD en todos los dataset
# con excepcion del dataset del 2011 el cual si contiene valores nulos
# Out:
# DataSet2010 ICD:  False
# DataSet2011 ICD:  True
# DataSet2012 ICD:  False
# DataSet2013 ICD:  False
# DataSet2014 ICD:  False
# DataSet2015 ICD:  False
# DataSet2016 ICD:  False
# DataSet2017 ICD:  False
# DataSet2018 ICD:  False
# DataSet2019 ICD:  False

# %% [markdown]
# ### Para saber si los valores distintos que hay en cada dataset en la columna ICD son coherentes

# %%
print('DataSet2010 valores distintos en ICD: ', df2010['ICD'].unique(), '\nCantidad de valores distintos: ', len(df2010['ICD'].unique()))
print('DataSet2011 valores distintos en ICD: ', df2011['ICD'].unique(), '\nCantidad de valores distintos: ', len(df2011['ICD'].unique()))
print('DataSet2012 valores distintos en ICD: ', df2012['ICD'].unique(), '\nCantidad de valores distintos: ', len(df2012['ICD'].unique()))
print('DataSet2013 valores distintos en ICD: ', df2013['ICD'].unique(), '\nCantidad de valores distintos: ', len(df2013['ICD'].unique()))
print('DataSet2014 valores distintos en ICD: ', df2014['ICD'].unique(), '\nCantidad de valores distintos: ', len(df2014['ICD'].unique()))
print('DataSet2015 valores distintos en ICD: ', df2015['ICD'].unique(), '\nCantidad de valores distintos: ', len(df2015['ICD'].unique()))
print('DataSet2016 valores distintos en ICD: ', df2016['ICD'].unique(), '\nCantidad de valores distintos: ', len(df2016['ICD'].unique()))
print('DataSet2017 valores distintos en ICD: ', df2017['ICD'].unique(), '\nCantidad de valores distintos: ', len(df2017['ICD'].unique()))
print('DataSet2018 valores distintos en ICD: ', df2018['ICD'].unique(), '\nCantidad de valores distintos: ', len(df2018['ICD'].unique()))
print('DataSet2019 valores distintos en ICD: ', df2019['ICD'].unique(), '\nCantidad de valores distintos: ', len(df2019['ICD'].unique()))

# En todas hay 36, salvo en el dataset del 2011 donde hay un valor diferente de mas (el valor nulo).
# Out:
# DataSet2010 valores distintos en ICD:  ['C44' 'C20' 'C49' 'C50' 'C73' 'C67' 'C71' 'C53' 'C56' 'C81' 'C14' 'C52'
#  'C96' 'C64' 'C16' 'C22' 'C40' 'C95' 'C62' 'C23' 'C34' 'C25' 'C15' 'C32'
#  'C61' 'C43' 'C69' 'C51' 'C90' 'C66' 'C30' 'C45' 'C72' 'C68' 'C42' 'C33']
# Cantidad de valores distintos:  36
# DataSet2011 valores distintos en ICD:  ['C20' 'C56' 'C53' 'C95' 'C69' 'C64' 'C50' 'C61' 'C49' 'C73' 'C71' 'C16'
#  'C40' 'C34' 'C14' 'C96' 'C44' 'C22' 'C23' 'C62' 'C25' 'C72' 'C90' 'C81'
#  'C67' 'C51' 'C15' 'C52' 'C32' 'C43' 'C45' 'C30' 'C66' 'C42' 'C68' 'C33'
#  nan]
# Cantidad de valores distintos:  37
# DataSet2012 valores distintos en ICD:  ['C56' 'C96' 'C49' 'C53' 'C50' 'C20' 'C95' 'C81' 'C71' 'C73' 'C64' 'C40'
#  'C61' 'C72' 'C25' 'C62' 'C16' 'C44' 'C67' 'C14' 'C90' 'C69' 'C34' 'C22'
#  'C23' 'C43' 'C51' 'C52' 'C32' 'C45' 'C15' 'C30' 'C33' 'C42' 'C68' 'C66']
# Cantidad de valores distintos:  36
# ...

# %% [markdown]
# ### Contar la frecuencia de cada valor distinto en la columna ICD

# %%
dfDefinitivo = pd.concat([df2010, df2011, df2012, df2013, df2014, df2015, df2016, df2017, df2018, df2019], ignore_index=True)

valores_distintos = dfDefinitivo['ICD'].value_counts(dropna=False)
nuevo_dataframe = pd.DataFrame({'llave': valores_distintos.index, 'Frecuencia': valores_distintos.values})
print(nuevo_dataframe)
# Out:
#    llave  Frecuencia
# 0    C50      242961
# 1    C95      220864
# 2    C53      120721
# 3    C20       69343
# 4    C96       43043
# 5    C56       35893
# 6    C44       34856
# 7    C62       32214
# 8    C61       30449
# 9    C40       27109
# 10   C49       24852
# 11   C71       23712
# 12   C16       23604
# 13   C34       22233
# 14   C14       20623
# 15   C25       19416
# 16   C64       15786
# 17   C73       13058
# 18   C81       12730
# 19   C22       11330
# 20   C67        9056
# 21   C32        8627
# 22   C90        8099
# 23   C23        6979
# 24   C43        6785
# 25   C15        6136
# 26   C72        4784
# 27   C69        4714
# 28   C52        4062
# 29   C51        3152
# 30   C30        1765
# 31   C45        1427
# 32   C66         479
# 33   C42         311
# 34   C33         188
# 35   C68         186
# 36   NaN           1

# %% [markdown]
# ### Armar la "tabla" que vendría a ser la descripción de las llaves cáncer

# %%
# Se toma el conjunto de 2011 para que salgan los 36 valores distintos y el valor extra (valor nulo) que sale en este dataset

df2011.drop_duplicates(subset='ICD')[['ICD', 'organ']].value_counts(dropna=False).count() # Los 36
descripCancer = df2011.drop_duplicates(subset='ICD')[['ICD', 'organ']]
print(descripCancer)
# Out:
#        ICD                    organ
# 0      C20         Colon and Rectum
# 1      C56                    Ovary
# 3      C53             Cervix Uteri
# 4      C95                 Leukemia
# 5      C69                     Eyes
# 6      C64                   Kidney
# 10     C50                   Breast
# 12     C61                 Prostate
# 15     C49              Soft Tissue
# 18     C73                  Thyroid
# 21     C71                    Brain
# 25     C16                  Stomach
# 27     C40                     Bone
# 29     C34                    Lungs
# 31     C14  Oral Cavity and Pharynx
# 32     C96                 Lymphoma
# 33     C44       Skin non Melanoma
# 40     C22                   Liver
# 42     C23              Gallbladder
# 56     C62                   Testis
# 97     C25                 Pancreas
# 99     C72                  Nervous
# 140    C90                 Mylenoma
# 195    C81       Hodgkin's Lymphoma
# 223    C67                  Bladder
# ...

# %% [markdown]
# ### Ahora si hacer el join con el dataset que tiene la descripción del tipo de cáncer

# %%
dfJoin = pd.merge(nuevo_dataframe, descripCancer, left_on='llave', right_on='ICD', how='inner')
print(dfJoin)
# Out:
#    llave  Frecuencia  ICD                    organ
# 0    C50      242961  C50                   Breast
# 1    C95      220864  C95                 Leukemia
# 2    C53      120721  C53             Cervix Uteri
# 3    C20       69343  C20         Colon and Rectum
# 4    C96       43043  C96                 Lymphoma
# 5    C56       35893  C56                    Ovary
# 6    C44       34856  C44       Skin non Melanoma
# 7    C62       32214  C62                   Testis
# 8    C61       30449  C61                 Prostate
# 9    C40       27109  C40                     Bone
# 10   C49       24852  C49              Soft Tissue
# 11   C71       23712  C71                    Brain
# 12   C16       23604  C16                  Stomach
# 13   C34       22233  C34                    Lungs
# 14   C14       20623  C14  Oral Cavity and Pharynx
# 15   C25       19416  C25                 Pancreas
# 16   C64       15786  C64                   Kidney
# ...

# %% [markdown]
# ### Graficar resultado

# %%
plt.figure(figsize=(12, 6))
plt.bar(dfJoin.index, dfJoin['Frecuencia'], color='#17becf', width=0.7)
plt.title('Cantidad de personas en cada categoría del cáncer en México en los años 2010 - 2019')
plt.xlabel('Nombre de la categoría del cáncer')
plt.ylabel('Frecuencia')

plt.xticks(dfJoin.index, dfJoin['organ'], rotation=90)
plt.grid(True)

# %% [markdown]
# # Análisis de los estados del país ------------------------------------------------------------------------------------------

# %%
# Verificar si alguno de los dataFrames en el campo ent_mx contiene valores nulos
isNuloEstado2010 = df2010['ent_mx'].isnull().any()
isNuloEstado2011 = df2011['ent_mx'].isnull().any()
isNuloEstado2012 = df2012['ent_mx'].isnull().any()
isNuloEstado2013 = df2013['ent_mx'].isnull().any()
isNuloEstado2014 = df2014['ent_mx'].isnull().any()
isNuloEstado2015 = df2015['ent_mx'].isnull().any()
isNuloEstado2016 = df2016['ent_mx'].isnull().any()
isNuloEstado2017 = df2017['ent_mx'].isnull().any()
isNuloEstado2018 = df2018['ent_mx'].isnull().any()
isNuloEstado2019 = df2019['ent_mx'].isnull().any()

print('DataSet2010 ent_mx: ', isNuloEstado2010)
print('DataSet2011 ent_mx: ', isNuloEstado2011)
print('DataSet2012 ent_mx: ', isNuloEstado2012)
print('DataSet2013 ent_mx: ', isNuloEstado2013)
print('DataSet2014 ent_mx: ', isNuloEstado2014)
print('DataSet2015 ent_mx: ', isNuloEstado2015)
print('DataSet2016 ent_mx: ', isNuloEstado2016)
print('DataSet2017 ent_mx: ', isNuloEstado2017)
print('DataSet2018 ent_mx: ', isNuloEstado2018)
print('DataSet2019 ent_mx: ', isNuloEstado2019)

# Se concluye que SI hay valores nulos en la columna ent_mx en todos los dataset, salvo en el dataset del año 2015,
# donde NO hay valores nulos.
# Out:
# DataSet2010 ent_mx:  True
# DataSet2011 ent_mx:  True
# DataSet2012 ent_mx:  True
# DataSet2013 ent_mx:  True
# DataSet2014 ent_mx:  True
# DataSet2015 ent_mx:  False
# DataSet2016 ent_mx:  True
# DataSet2017 ent_mx:  True
# DataSet2018 ent_mx:  True
# DataSet2019 ent_mx:  True

# %% [markdown]
# ### Para saber si los valores distintos que hay en cada dataset en la columna que representa al nombre del estado son coherentes

# %%
print('DataSet2010 valores distintos en ent_mx: \n', df2010['ent_mx'].unique(), '\nCantidad de valores distintos: ', len(df2010['ent_mx'].unique()))
print('DataSet2011 valores distintos en ent_mx: \n', df2011['ent_mx'].unique(), '\nCantidad de valores distintos: ', len(df2011['ent_mx'].unique()))
print('DataSet2012 valores distintos en ent_mx: \n', df2012['ent_mx'].unique(), '\nCantidad de valores distintos: ', len(df2012['ent_mx'].unique()))
print('DataSet2013 valores distintos en ent_mx: \n', df2013['ent_mx'].unique(), '\nCantidad de valores distintos: ', len(df2013['ent_mx'].unique()))
print('DataSet2014 valores distintos en ent_mx: \n', df2014['ent_mx'].unique(), '\nCantidad de valores distintos: ', len(df2014['ent_mx'].unique()))
print('DataSet2015 valores distintos en ent_mx: \n', df2015['ent_mx'].unique(), '\nCantidad de valores distintos: ', len(df2015['ent_mx'].unique()))
print('DataSet2016 valores distintos en ent_mx: \n', df2016['ent_mx'].unique(), '\nCantidad de valores distintos: ', len(df2016['ent_mx'].unique()))
print('DataSet2017 valores distintos en ent_mx: \n', df2017['ent_mx'].unique(), '\nCantidad de valores distintos: ', len(df2017['ent_mx'].unique()))
print('DataSet2018 valores distintos en ent_mx: \n', df2018['ent_mx'].unique(), '\nCantidad de valores distintos: ', len(df2018['ent_mx'].unique()))
print('DataSet2019 valores distintos en ent_mx: \n', df2019['ent_mx'].unique(), '\nCantidad de valores distintos: ', len(df2019['ent_mx'].unique()))

# En todos los dataset's hay 34 valores distintos, salvo en algunos años.
# Hay 34, hay uno de mas porque hay 32 estados en el pais y se contempla uno mas (el valor nulo). Entonces cual esta de sobra????
# En el año 2013 hay 33 valores distintos porque no esta el valor de EU y en el 2015 hay 32 valores distintos porque no hubo valores nulos y no estuvo
# el valor de eu.
# Out:
# DataSet2010 valores distintos en ent_mx:
#  ['Nuevo León' 'Coahuila de Zaragoza' 'Durango' 'Zacatecas' 'Campeche'
#  'Tamaulipas' 'Nayarit' 'Oaxaca' 'Veracruz de Ignacio de la Llave'
#  'Puebla' 'Tlaxcala' 'Guerrero' 'Baja California' 'Distrito Federal'
#  'Quintana Roo' 'Querétaro' 'Guanajuato' 'Michoacán de Ocampo'
#  'San Luis Potosí' 'Hidalgo' 'Sinaloa' 'Chihuahua' 'Sonora' 'Colima'
#  'Jalisco' 'Tabasco' 'Chiapas' 'Yucatán' 'México' 'Aguascalientes'
#  'Baja California Sur' 'Morelos' nan 'Estados unidos de America']
# Cantidad de valores distintos:  34
# DataSet2011 valores distintos en ent_mx:
#  ['Quintana Roo' 'Oaxaca' 'Guerrero' 'Puebla' 'Distrito Federal'
#  'Veracruz de Ignacio de la Llave' 'Colima' 'Tlaxcala' 'Morelos'
#  'Querétaro' 'Guanajuato' 'Jalisco' 'San Luis Potosí' 'México' 'Hidalgo'
#  'Nuevo León' 'Zacatecas' 'Tamaulipas' 'Sinaloa' 'Durango' 'Sonora'
#  'Chihuahua' 'Baja California Sur' 'Tabasco' 'Chiapas' 'Campeche' nan
# ...

# %% [markdown]
# ### Contar la frecuencia de cada valor distinto en la columna ent_mx

# %%
dfDefinitivo = pd.concat([df2010, df2011, df2012, df2013, df2014, df2015, df2016, df2017, df2018, df2019], ignore_index=True)

valores_distintos = dfDefinitivo['ent_mx'].value_counts(dropna=False)
nuevo_dataframe = pd.DataFrame({'llave': valores_distintos.index, 'Frecuencia': valores_distintos.values})
print(nuevo_dataframe)
# Out:
#                               llave  Frecuencia
# 0               Michoacán de Ocampo      218121
# 1                           Jalisco      137212
# 2                            Sonora       76061
# 3                            México       75997
# 4                  Distrito Federal       63586
# 5   Veracruz de Ignacio de la Llave       56997
# 6                           Durango       55402
# 7                           Tabasco       48602
# 8                        Guanajuato       40571
# 9                            Oaxaca       39294
# 10                        Chihuahua       36167
# 11                           Puebla       26657
# 12                   Aguascalientes       26178
# 13                          Chiapas       23878
# 14                       Tamaulipas       14965
# 15                        Zacatecas       14580
# 16              Baja California Sur       14324
# 17                  San Luis Potosí       13528
# 18                          Hidalgo       12852
# ...

# %% [markdown]
# ### Graficar resultado

# %%
plt.figure(figsize=(12, 6))
plt.bar(nuevo_dataframe.index, nuevo_dataframe['Frecuencia'], color='#bcbd22', width=0.7)
plt.title('Cantidad de personas con algún tipo de cáncer en cada estado del país en México en los años 2010 - 2019')
plt.xlabel('Nombre del Estado')
plt.ylabel('Frecuencia')

plt.xticks(nuevo_dataframe.index, nuevo_dataframe['llave'], rotation=90)
plt.grid(True)

# Tras observar la grafica y las frecuencias se determino que el estado que sobra es: "Estados unidos de america"
