# %% [markdown]
# <a href="https://colab.research.google.com/github/aledelorbe/pt2Codigos/blob/main/PrimerasActividades/Sesgo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Cargar librerias

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Cargar los dataFrame

# %%
nuevaMortalidadLimpia = '/content/drive/MyDrive/Pt2/Primeras Actividades/0 Bases de Datos/Nueva Mortalidad Limpia/'

df2010 = pd.read_csv(nuevaMortalidadLimpia + '2010.csv')
df2011 = pd.read_csv(nuevaMortalidadLimpia + '2011.csv')
df2012 = pd.read_csv(nuevaMortalidadLimpia + '2012.csv')
df2013 = pd.read_csv(nuevaMortalidadLimpia + '2013.csv')
df2014 = pd.read_csv(nuevaMortalidadLimpia + '2014.csv')
df2015 = pd.read_csv(nuevaMortalidadLimpia + '2015.csv')
df2016 = pd.read_csv(nuevaMortalidadLimpia + '2016.csv')
df2017 = pd.read_csv(nuevaMortalidadLimpia + '2017.csv')
df2018 = pd.read_csv(nuevaMortalidadLimpia + '2018.csv')
df2019 = pd.read_csv(nuevaMortalidadLimpia + '2019.csv')

# %% [markdown]
# ### Unir todos los fragmentos

# %%
dfDefinitivo = pd.concat([df2010, df2011, df2012, df2013, df2014, df2015, df2016, df2017, df2018, df2019], ignore_index=True)

# %% [markdown]
# ### Establecimiento de Sesgo

# %%
# Definicion de la funcion de sesgo
def sesgo(columna, titulo, color):
  resultado = dfDefinitivo[columna].value_counts(dropna=False)
  fig = plt.figure(figsize=(10, 6))
  plt.title(f'Cantidad de personas con cancer en cada {titulo} México')
  plt.bar(resultado.index, resultado.values, color=color)
  plt.grid()
  plt.tick_params(axis='x', labelsize=12, rotation=90)

# %% [markdown]
# #### Estado

# %%
sesgo('ent_resid_nm', 'estado de', 'blue')

# %% [markdown]
# #### Tipo de Cancer

# %%
sesgo('Organ', 'tipo de cancer en', 'yellow')

# %% [markdown]
# #### Nivel Educativo

# %%
sesgo('desc_escolaridad', 'nivel educativo en', 'green')

# %% [markdown]
# #### Categoria de Ocupación

# %%
sesgo('desc_ocupacion', 'categoria de ocupacion en', 'red')
